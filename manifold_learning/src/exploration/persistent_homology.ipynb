# %% [markdown]
# # Persistent Homology Exploration

# %%
import numpy as np
from ripser import ripser
from persim import plot_diagrams, bottleneck

# Original and embedded distance matrices (examples)
# D_original = np.array([[0, 2, 4], [2, 0, 3], [4, 3, 0]])  # Replace with your matrix
# D_embedded = np.array([[0, 1.9, 4.1], [1.9, 0, 3.2], [4.1, 3.2, 0]])
D_original = np.load("/Users/damian_gerber/Library/Mobile Documents/com~apple~CloudDocs/01 - Master Mathematics/MIT/Thesis/thesis_dgerber/src/data/graph_data/D_mat.npy")

# Compute persistence diagrams
original_diagrams = ripser(D_original, distance_matrix=True)['dgms']
# embedded_diagrams = ripser(D_embedded, distance_matrix=True)['dgms']

# Plot persistence diagrams
plot_diagrams(original_diagrams, title="Original Persistence Diagram")
# plot_diagrams(embedded_diagrams, title="Embedded Persistence Diagram")

# # Compute bottleneck distance between diagrams (dimension 0 features)
# bottleneck_dist = bottleneck(original_diagrams[0], embedded_diagrams[0])
# print(f"Bottleneck distance (Dimension 0): {bottleneck_dist}")
